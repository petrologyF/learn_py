# %% [markdown]
# # Chapter 4: Geospatial Analysis with Geopandas and Rasterio
#
# Working with DEM and GIS data.

# %%
import rasterio
# Open the synthetic DEM
with rasterio.open('../data/synthetic_dem.tif') as src:
    data = src.read(1)
    print(data.shape)

# %% [markdown]
# ## Exercise 4-1: DEM Stats
# Return min, max, mean of the DEM.

# %%
def exercise_ch04_dem_stats(tif_path):
    # TODO: Implement
    pass
