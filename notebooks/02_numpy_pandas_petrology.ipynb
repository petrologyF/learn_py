# %% [markdown]
# # Chapter 2: NumPy and Pandas in Petrology
#
# Handling rock composition data.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../data/rock_composition.csv')
df.head()

# %% [markdown]
# ## Exercise 2-1: Normalization
# Normalize the wt% to sum to 100%.

# %%
def exercise_ch02_composition(df):
    # TODO: Implement
    pass
