# %% [markdown]
# <div style='display:flex; justify-content:space-between;'><span>[← Previous Chapter: 04_image_geometry.ipynb](04_image_geometry.ipynb)</span><span>[Table of Contents](00_introduction.ipynb)</span><span>[Next Chapter: 06_geochemistry_clustering.ipynb →](06_geochemistry_clustering.ipynb)</span></div>

# %%
import sys
import os
sys.path.append('../')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.verifier import verify_and_log

sns.set_theme(style='whitegrid')
pd.options.display.max_columns = None

# %% [markdown]
# # #05 3D解析
#
# ## 0. 背景：地下構造の可視化
# PyVistaを用いて、3次元的な地質モデルの基礎となる格子データを扱います。

# %% [markdown]
# ## 課題：自動解析パイプラインの構築
# 学んだ手法を組み合わせて、一連の処理を完結させる関数を実装してください。

# %%
import pyvista as pv
def run_module_pipeline():
    grid = pv.UniformGrid(dimensions=(10,10,10))
    grid.cell_data['Val'] = np.random.rand(grid.n_cells)
    return {'Cells': grid.n_cells, 'Status': 'Success'}

# %% [markdown]
# ## 結果の視覚化
# 解析結果をグラフで確認します。

# %% [markdown]
# ## 検証と記録
# 関数を実行し、結果を検証エンジンで確認します。

# %%
result = run_module_pipeline()
verify_and_log('M5', result)

# %% [markdown]
# ## 演習問題
# 格子サイズを (50, 50, 50) に変更した場合の総セル数を計算し、表示してください。

# %% [markdown]
# **回答（期待される出力）**
#
# ```
# 総セル数 (50x50x50): 117649
# ```

# %%
# 演習の解答をここに記述してください

# %% [markdown]
# <div style='display:flex; justify-content:space-between;'><span>[← Previous Chapter: 04_image_geometry.ipynb](04_image_geometry.ipynb)</span><span>[Table of Contents](00_introduction.ipynb)</span><span>[Next Chapter: 06_geochemistry_clustering.ipynb →](06_geochemistry_clustering.ipynb)</span></div>
