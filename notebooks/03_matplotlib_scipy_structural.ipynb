# %% [markdown]
# # Chapter 3: Matplotlib and SciPy in Structural Geology
#
# Visualizing orientation data.

# %%
import pandas as pd
df = pd.read_csv('../data/structural_faults.csv')
df.head()

# %% [markdown]
# ## Exercise 3-1: Filter Outliers
# Remove dips outside [0, 90].

# %%
def exercise_ch03_filter_outliers(df):
    # TODO: Implement
    pass
