# %% [markdown]
# # Chapter 1: Basic Python and Jupyter
#
# This notebook introduces basic Python syntax and how to use Jupyter.

# %%
print('Hello, Earth Science!')

# %% [markdown]
# ## Exercise 1-1
# Implement a function that returns the square of a number.

# %%
def exercise_ch01_square(n):
    # TODO: Implement
    pass
