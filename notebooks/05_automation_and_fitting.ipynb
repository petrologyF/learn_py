# %% [markdown]
# # Chapter 5: Automation and Curve Fitting
#
# Automating the analysis pipeline.

# %%
from scipy import optimize
import numpy as np
# Sample data
x = np.linspace(0, 10, 100)
y = 2.5 * x + 5 + np.random.normal(0, 1, 100)

# %% [markdown]
# ## Exercise 5-1: Linear Fitting
# Fit y = ax + b and return (a, b).

# %%
def exercise_ch05_linear_fit(x, y):
    # TODO: Implement
    pass
